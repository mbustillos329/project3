# %%
# dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf
import pandas as pd 

from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.xception import (
    Xception, preprocess_input, decode_predictions)

# %%
# xception model
model = Xception(
    include_top=True,
    weights='imagenet')

# %%
# default image size
image_size = (299,299)

# %%
# load image and resize 
image_path = os.path.join("..", "project3", "data", "1.jpg")
# /Users/monicabustillos/Documents/project3/data
print(image_path)
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Out:
# ../project3/data/1.jpg

# %%
# preprocess image
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
# predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3)[0])
plt.imshow(img)
# Out:
# Predicted: [('n02123045', 'tabby', 0.6031961), ('n02123159', 'tiger_cat', 0.14564592), ('n02124075', 'Egyptian_cat', 0.098369844)]

# %%
# Refactor above steps into reusable function
def predict(image_path):
    """Use Xception to label image"""
    img = image.load_img(image_path, target_size=image_size)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    predictions = model.predict(x)
    return  decode_predictions(predictions, top=3)[0]

# %%
image_path = os.path.join("..", "project3", "data", "2.jpg")

cur_preds = predict(image_path)
cur_preds
# Out:
# [('n06359193', 'web_site', 0.31165108),
#  ('n02123045', 'tabby', 0.18851222),
#  ('n02124075', 'Egyptian_cat', 0.08512939)]

# %%
# pred = decode_predictions(predictions, top=3)[0]
directory = "/Users/monicabustillos/Documents/project3/data"
prediction_list = []
for file in os.listdir(directory):
    if file.endswith(".jpg"):
        image_path = os.path.join("..", "project3", "data", file)
        variable = predict(image_path)
#         print(variable)
        for item in variable:
            prediction_list.append({
                'Image': file,
                'Prediction': item[1],
                'Probability': item[2],
            })

# %%
prediction_list
# Out:
# [{'Image': '63.jpg', 'Prediction': 'basset', 'Probability': 0.2638782},
#  {'Image': '63.jpg', 'Prediction': 'bloodhound', 'Probability': 0.043251116},
#  {'Image': '63.jpg', 'Prediction': 'Great_Dane', 'Probability': 0.041339852},
#  {'Image': '62.jpg',
#   'Prediction': 'Labrador_retriever',
#   'Probability': 0.9508597},
#  {'Image': '62.jpg',
#   'Prediction': 'golden_retriever',
#   'Probability': 0.01688259},
#  {'Image': '62.jpg',
#   'Prediction': 'flat-coated_retriever',
#   'Probability': 0.008420618},
#  {'Image': '60.jpg', 'Prediction': 'basenji', 'Probability': 0.08317219},
#  {'Image': '60.jpg',
#   'Prediction': 'English_foxhound',
#   'Probability': 0.07371726},
#  {'Image': '60.jpg',
#   'Prediction': 'American_Staffordshire_terrier',
#   'Probability': 0.06596607},
#  {'Image': '48.jpg',
#   'Prediction': 'English_springer',
#   'Probability': 0.6916187},
#  {'Image': '48.jpg',
#   'Prediction': 'Welsh_springer_spaniel',
#   'Probability': 0.037468433},
#  {'Image': '48.jpg',
#   'Prediction': 'Sussex_spaniel',
#   'Probability': 0.021113051},
#  {'Image': '49.jpg', 'Prediction': 'collie', 'Probability': 0.6558191},
#  {'Image': '49.jpg',
#   'Prediction': 'Shetland_sheepdog',
#   'Probability': 0.1137496},
#  {'Image': '49.jpg', 'Prediction': 'chow', 'Probability': 0.019973408},
#  {'Image': '61.jpg',
#   'Prediction': 'American_Staffordshire_terrier',
#   'Probability': 0.9310916},
#  {'Image': '61.jpg',
#   'Prediction': 'Staffordshire_bullterrier',
#   'Probability': 0.024593756},
#  {'Image': '61.jpg', 'Prediction': 'bull_mastiff', 'Probability': 0.01246345},
#  {'Image': '59.jpg',
#   'Prediction': 'Rhodesian_ridgeback',
#   'Probability': 0.5861812},
#  {'Image': '59.jpg', 'Prediction': 'redbone', 'Probability': 0.34169966},
#  {'Image': '59.jpg', 'Prediction': 'vizsla', 'Probability': 0.024720207},
#  {'Image': '65.jpg', 'Prediction': 'Leonberg', 'Probability': 0.6695496},
#  {'Image': '65.jpg',
#   'Prediction': 'German_shepherd',
#   'Probability': 0.062318247},
#  {'Image': '65.jpg',
#   'Prediction': 'Norwegian_elkhound',
#   'Probability': 0.043854706},
#  {'Image': '64.jpg',
#   'Prediction': 'Labrador_retriever',
#   'Probability': 0.9589946},
#  {'Image': '64.jpg',
#   'Prediction': 'flat-coated_retriever',
#   'Probability': 0.0061921943},
#  {'Image': '64.jpg',
#   'Prediction': 'German_short-haired_pointer',
#   'Probability': 0.0050597284},
#  {'Image': '58.jpg', 'Prediction': 'beagle', 'Probability': 0.55029595},
#  {'Image': '58.jpg',
#   'Prediction': 'black-and-tan_coonhound',
#   'Probability': 0.097152494},
#  {'Image': '58.jpg', 'Prediction': 'Walker_hound', 'Probability': 0.07817557},
#  {'Image': '8.jpg', 'Prediction': 'toy_terrier', 'Probability': 0.15955561},
#  {'Image': '8.jpg', 'Prediction': 'whippet', 'Probability': 0.14947401},
#  {'Image': '8.jpg',
#   'Prediction': 'wire-haired_fox_terrier',
#   'Probability': 0.11511639},
#  {'Image': '9.jpg',
#   'Prediction': 'Italian_greyhound',
#   'Probability': 0.3841865},
#  {'Image': '9.jpg',
#   'Prediction': 'Mexican_hairless',
#   'Probability': 0.13544258},
#  {'Image': '9.jpg', 'Prediction': 'whippet', 'Probability': 0.03530783},
#  {'Image': '14.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.53400487},
#  {'Image': '14.jpg', 'Prediction': 'tabby', 'Probability': 0.2114152},
#  {'Image': '14.jpg', 'Prediction': 'tiger_cat', 'Probability': 0.060526974},
#  {'Image': '28.jpg', 'Prediction': 'tiger_cat', 'Probability': 0.4280094},
#  {'Image': '28.jpg', 'Prediction': 'tabby', 'Probability': 0.27948722},
#  {'Image': '28.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.066126704},
#  {'Image': '29.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.56813043},
#  {'Image': '29.jpg', 'Prediction': 'tabby', 'Probability': 0.25324273},
#  {'Image': '29.jpg', 'Prediction': 'tiger_cat', 'Probability': 0.10120913},
#  {'Image': '15.jpg', 'Prediction': 'Persian_cat', 'Probability': 0.06934102},
#  {'Image': '15.jpg', 'Prediction': 'tabby', 'Probability': 0.06771823},
#  {'Image': '15.jpg', 'Prediction': 'tiger_cat', 'Probability': 0.041978687},
#  {'Image': '17.jpg', 'Prediction': 'tabby', 'Probability': 0.27407768},
#  {'Image': '17.jpg', 'Prediction': 'Persian_cat', 'Probability': 0.14697249},
#  {'Image': '17.jpg', 'Prediction': 'lynx', 'Probability': 0.11099436},
#  {'Image': '16.jpg', 'Prediction': 'Persian_cat', 'Probability': 0.06509116},
#  {'Image': '16.jpg', 'Prediction': 'sleeping_bag', 'Probability': 0.047519617},
#  {'Image': '16.jpg', 'Prediction': 'tabby', 'Probability': 0.043324824},
#  {'Image': '13.jpg', 'Prediction': 'Persian_cat', 'Probability': 0.4118691},
#  {'Image': '13.jpg', 'Prediction': 'tabby', 'Probability': 0.03830366},
#  {'Image': '13.jpg', 'Prediction': 'lynx', 'Probability': 0.027990244},
#  {'Image': '39.jpg', 'Prediction': 'studio_couch', 'Probability': 0.07877126},
#  {'Image': '39.jpg', 'Prediction': 'quilt', 'Probability': 0.06550851},
#  {'Image': '39.jpg', 'Prediction': 'Siamese_cat', 'Probability': 0.055627238},
#  {'Image': '11.jpg',
#   'Prediction': 'flat-coated_retriever',
#   'Probability': 0.7184418},
#  {'Image': '11.jpg',
#   'Prediction': 'curly-coated_retriever',
#   'Probability': 0.02919132},
#  {'Image': '11.jpg', 'Prediction': 'Newfoundland', 'Probability': 0.02785005},
#  {'Image': '10.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.114343144},
#  {'Image': '10.jpg', 'Prediction': 'tabby', 'Probability': 0.09047055},
#  {'Image': '10.jpg', 'Prediction': 'Siamese_cat', 'Probability': 0.07473839},
#  {'Image': '38.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.18134584},
#  {'Image': '38.jpg', 'Prediction': 'Siamese_cat', 'Probability': 0.11528554},
#  {'Image': '38.jpg', 'Prediction': 'quilt', 'Probability': 0.1150956},
#  {'Image': '21.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.5887546},
#  {'Image': '21.jpg', 'Prediction': 'tabby', 'Probability': 0.15857248},
#  {'Image': '21.jpg', 'Prediction': 'tiger_cat', 'Probability': 0.13639754},
#  {'Image': '35.jpg', 'Prediction': 'hamper', 'Probability': 0.52339786},
#  {'Image': '35.jpg', 'Prediction': 'bassinet', 'Probability': 0.0463365},
#  {'Image': '35.jpg',
#   'Prediction': 'shopping_basket',
#   'Probability': 0.04111128},
#  {'Image': '34.jpg', 'Prediction': 'tabby', 'Probability': 0.37064615},
#  {'Image': '34.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.3416523},
#  {'Image': '34.jpg', 'Prediction': 'tiger_cat', 'Probability': 0.075616345},
#  {'Image': '20.jpg',
#   'Prediction': 'Staffordshire_bullterrier',
#   'Probability': 0.47783148},
#  {'Image': '20.jpg',
#   'Prediction': 'American_Staffordshire_terrier',
#   'Probability': 0.33536634},
#  {'Image': '20.jpg', 'Prediction': 'bull_mastiff', 'Probability': 0.063400045},
#  {'Image': '36.jpg', 'Prediction': 'tiger_cat', 'Probability': 0.14794965},
#  {'Image': '36.jpg', 'Prediction': 'tabby', 'Probability': 0.14753035},
#  {'Image': '36.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.109481186},
#  {'Image': '22.jpg', 'Prediction': 'Persian_cat', 'Probability': 0.65957844},
#  {'Image': '22.jpg', 'Prediction': 'tabby', 'Probability': 0.12132072},
#  {'Image': '22.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.045737598},
#  {'Image': '23.jpg',
#   'Prediction': 'wire-haired_fox_terrier',
#   'Probability': 0.24501961},
#  {'Image': '23.jpg', 'Prediction': 'papillon', 'Probability': 0.0941429},
#  {'Image': '23.jpg', 'Prediction': 'toy_terrier', 'Probability': 0.07053768},
#  {'Image': '37.jpg', 'Prediction': 'tabby', 'Probability': 0.53071576},
#  {'Image': '37.jpg', 'Prediction': 'tiger_cat', 'Probability': 0.23537254},
#  {'Image': '37.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.082895115},
#  {'Image': '33.jpg',
#   'Prediction': 'Tibetan_mastiff',
#   'Probability': 0.16496529},
#  {'Image': '33.jpg', 'Prediction': 'collie', 'Probability': 0.07141978},
#  {'Image': '33.jpg', 'Prediction': 'malamute', 'Probability': 0.06407275},
#  {'Image': '27.jpg', 'Prediction': 'Pomeranian', 'Probability': 0.32760826},
#  {'Image': '27.jpg', 'Prediction': 'bucket', 'Probability': 0.05296317},
#  {'Image': '27.jpg', 'Prediction': 'Persian_cat', 'Probability': 0.04912275},
#  {'Image': '26.jpg', 'Prediction': 'tabby', 'Probability': 0.5235008},
#  {'Image': '26.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.06841774},
#  {'Image': '26.jpg', 'Prediction': 'tiger_cat', 'Probability': 0.057925172},
#  {'Image': '32.jpg', 'Prediction': 'Appenzeller', 'Probability': 0.07639531},
#  {'Image': '32.jpg',
#   'Prediction': 'miniature_pinscher',
#   'Probability': 0.06755941},
#  {'Image': '32.jpg', 'Prediction': 'beagle', 'Probability': 0.057652652},
#  {'Image': '18.jpg', 'Prediction': 'tabby', 'Probability': 0.4423765},
#  {'Image': '18.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.31316817},
#  {'Image': '18.jpg', 'Prediction': 'tiger_cat', 'Probability': 0.07515811},
#  {'Image': '24.jpg', 'Prediction': 'redbone', 'Probability': 0.96055365},
#  {'Image': '24.jpg',
#   'Prediction': 'Rhodesian_ridgeback',
#   'Probability': 0.028515033},
#  {'Image': '24.jpg', 'Prediction': 'vizsla', 'Probability': 0.0028841419},
#  {'Image': '30.jpg', 'Prediction': 'tabby', 'Probability': 0.5087659},
#  {'Image': '30.jpg', 'Prediction': 'tiger_cat', 'Probability': 0.11902676},
#  {'Image': '30.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.10534194},
#  {'Image': '31.jpg', 'Prediction': 'tabby', 'Probability': 0.25606284},
#  {'Image': '31.jpg', 'Prediction': 'tiger_cat', 'Probability': 0.11243611},
#  {'Image': '31.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.07795634},
#  {'Image': '25.jpg', 'Prediction': 'window_screen', 'Probability': 0.28098515},
#  {'Image': '25.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.2218123},
#  {'Image': '25.jpg', 'Prediction': 'tabby', 'Probability': 0.032540493},
#  {'Image': '19.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.2790581},
#  {'Image': '19.jpg', 'Prediction': 'tabby', 'Probability': 0.21138276},
#  {'Image': '19.jpg', 'Prediction': 'tiger_cat', 'Probability': 0.08303238},
#  {'Image': '42.jpg', 'Prediction': 'Angora', 'Probability': 0.101764664},
#  {'Image': '42.jpg', 'Prediction': 'groenendael', 'Probability': 0.090936825},
#  {'Image': '42.jpg', 'Prediction': 'affenpinscher', 'Probability': 0.08541338},
#  {'Image': '4.jpg', 'Prediction': 'redbone', 'Probability': 0.17910199},
#  {'Image': '4.jpg', 'Prediction': 'Irish_terrier', 'Probability': 0.11745481},
#  {'Image': '4.jpg',
#   'Prediction': 'Rhodesian_ridgeback',
#   'Probability': 0.0527701},
#  {'Image': '56.jpg', 'Prediction': 'toy_terrier', 'Probability': 0.713139},
#  {'Image': '56.jpg', 'Prediction': 'Chihuahua', 'Probability': 0.22228198},
#  {'Image': '56.jpg',
#   'Prediction': 'Italian_greyhound',
#   'Probability': 0.006493457},
#  {'Image': '5.jpg', 'Prediction': 'Gordon_setter', 'Probability': 0.78772616},
#  {'Image': '5.jpg',
#   'Prediction': 'black-and-tan_coonhound',
#   'Probability': 0.07302635},
#  {'Image': '5.jpg', 'Prediction': 'toy_terrier', 'Probability': 0.012978022},
#  {'Image': '57.jpg',
#   'Prediction': 'English_setter',
#   'Probability': 0.98678464},
#  {'Image': '57.jpg', 'Prediction': 'clumber', 'Probability': 0.0010894832},
#  {'Image': '57.jpg',
#   'Prediction': 'cocker_spaniel',
#   'Probability': 0.00045911566},
#  {'Image': '43.jpg', 'Prediction': 'tabby', 'Probability': 0.5422469},
#  {'Image': '43.jpg', 'Prediction': 'Persian_cat', 'Probability': 0.07408996},
#  {'Image': '43.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.07348756},
#  {'Image': '55.jpg', 'Prediction': 'vizsla', 'Probability': 0.5191784},
#  {'Image': '55.jpg',
#   'Prediction': 'American_Staffordshire_terrier',
#   'Probability': 0.15197071},
#  {'Image': '55.jpg',
#   'Prediction': 'miniature_pinscher',
#   'Probability': 0.042152867},
#  {'Image': '7.jpg', 'Prediction': 'Persian_cat', 'Probability': 0.1600493},
#  {'Image': '7.jpg',
#   'Prediction': 'computer_keyboard',
#   'Probability': 0.059338972},
#  {'Image': '7.jpg',
#   'Prediction': 'Shetland_sheepdog',
#   'Probability': 0.019647857},
#  {'Image': '41.jpg', 'Prediction': 'tabby', 'Probability': 0.200981},
#  {'Image': '41.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.08331419},
#  {'Image': '41.jpg', 'Prediction': 'tiger_cat', 'Probability': 0.08262441},
#  {'Image': '40.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.3416953},
#  {'Image': '40.jpg', 'Prediction': 'Siamese_cat', 'Probability': 0.08399233},
#  {'Image': '40.jpg', 'Prediction': 'tabby', 'Probability': 0.07466144},
#  {'Image': '54.jpg', 'Prediction': 'hog', 'Probability': 0.099211484},
#  {'Image': '54.jpg',
#   'Prediction': 'French_bulldog',
#   'Probability': 0.09393593},
#  {'Image': '54.jpg',
#   'Prediction': 'American_black_bear',
#   'Probability': 0.0563389},
#  {'Image': '6.jpg', 'Prediction': 'Cardigan', 'Probability': 0.46364078},
#  {'Image': '6.jpg', 'Prediction': 'kelpie', 'Probability': 0.19924828},
#  {'Image': '6.jpg', 'Prediction': 'Chihuahua', 'Probability': 0.045236547},
#  {'Image': '2.jpg', 'Prediction': 'web_site', 'Probability': 0.31165108},
#  {'Image': '2.jpg', 'Prediction': 'tabby', 'Probability': 0.18851222},
#  {'Image': '2.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.08512939},
#  {'Image': '50.jpg',
#   'Prediction': 'English_foxhound',
#   'Probability': 0.28955647},
#  {'Image': '50.jpg', 'Prediction': 'beagle', 'Probability': 0.12962914},
#  {'Image': '50.jpg', 'Prediction': 'Walker_hound', 'Probability': 0.08817272},
#  {'Image': '44.jpg', 'Prediction': 'skunk', 'Probability': 0.062240932},
#  {'Image': '44.jpg', 'Prediction': 'shopping_cart', 'Probability': 0.04363904},
#  {'Image': '44.jpg',
#   'Prediction': 'shopping_basket',
#   'Probability': 0.04065341},
#  {'Image': '45.jpg',
#   'Prediction': 'Siberian_husky',
#   'Probability': 0.48453757},
#  {'Image': '45.jpg', 'Prediction': 'Eskimo_dog', 'Probability': 0.4033902},
#  {'Image': '45.jpg', 'Prediction': 'dogsled', 'Probability': 0.016841821},
#  {'Image': '3.jpg', 'Prediction': 'Siamese_cat', 'Probability': 0.29765722},
#  {'Image': '3.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.15339904},
#  {'Image': '3.jpg', 'Prediction': 'tabby', 'Probability': 0.058009848},
#  {'Image': '51.jpg', 'Prediction': 'bloodhound', 'Probability': 0.7875667},
#  {'Image': '51.jpg', 'Prediction': 'basset', 'Probability': 0.08433404},
#  {'Image': '51.jpg',
#   'Prediction': 'black-and-tan_coonhound',
#   'Probability': 0.009510962},
#  {'Image': '47.jpg',
#   'Prediction': 'miniature_poodle',
#   'Probability': 0.43182024},
#  {'Image': '47.jpg',
#   'Prediction': 'standard_poodle',
#   'Probability': 0.29773396},
#  {'Image': '47.jpg', 'Prediction': 'toy_poodle', 'Probability': 0.16611272},
#  {'Image': '53.jpg',
#   'Prediction': 'Chesapeake_Bay_retriever',
#   'Probability': 0.6897293},
#  {'Image': '53.jpg', 'Prediction': 'vizsla', 'Probability': 0.06522424},
#  {'Image': '53.jpg', 'Prediction': 'bloodhound', 'Probability': 0.042469285},
#  {'Image': '1.jpg', 'Prediction': 'tabby', 'Probability': 0.6031961},
#  {'Image': '1.jpg', 'Prediction': 'tiger_cat', 'Probability': 0.14564592},
#  {'Image': '1.jpg', 'Prediction': 'Egyptian_cat', 'Probability': 0.098369844},
#  {'Image': '52.jpg', 'Prediction': 'Border_collie', 'Probability': 0.8438759},
#  {'Image': '52.jpg', 'Prediction': 'collie', 'Probability': 0.0732602},
#  {'Image': '52.jpg',
#   'Prediction': 'English_springer',
#   'Probability': 0.029902432},
#  {'Image': '46.jpg',
#   'Prediction': 'Yorkshire_terrier',
#   'Probability': 0.45972508},
#  {'Image': '46.jpg', 'Prediction': 'silky_terrier', 'Probability': 0.26859364},
#  {'Image': '46.jpg',
#   'Prediction': 'Australian_terrier',
#   'Probability': 0.07266997}]

# %%
df = pd.DataFrame.from_dict(prediction_list)
df.head()
# Out:
#     Image          Prediction  Probability
# 0  63.jpg              basset     0.263878
# 1  63.jpg          bloodhound     0.043251
# 2  63.jpg          Great_Dane     0.041340
# 3  62.jpg  Labrador_retriever     0.950860
# 4  62.jpg    golden_retriever     0.016883

# %%
df['Breed Prediction'] = df['Prediction'].replace("_"," ")
df.head()
# Out:
#     Image          Prediction  Probability    Breed Prediction
# 0  63.jpg              basset     0.263878              basset
# 1  63.jpg          bloodhound     0.043251          bloodhound
# 2  63.jpg          Great_Dane     0.041340          Great_Dane
# 3  62.jpg  Labrador_retriever     0.950860  Labrador_retriever
# 4  62.jpg    golden_retriever     0.016883    golden_retriever

# %%
df["Probability Percentage"] = round(df["Probability"]*100,2)
df.head()
# Out:
#     Image          Prediction  Probability  Probability Percentage
# 0  63.jpg              basset     0.263878                   26.39
# 1  63.jpg          bloodhound     0.043251                    4.33
# 2  63.jpg          Great_Dane     0.041340                    4.13
# 3  62.jpg  Labrador_retriever     0.950860                   95.09
# 4  62.jpg    golden_retriever     0.016883                    1.69

# %%
df.to_csv("ml_data.csv",index=True)
